# %% [markdown]
# # Module 3:

# %%
# import Pkg
# Pkg.add(["Plots", "PlotlyJS", "PlotlyBase", "PlotlyKaleido" , "SymPy"])
using Plots
using SymPy
# Activate the interactive Plotly backend
plotly()
# Out:
# Plots.PlotlyBackend()

# %% [markdown]
# ## 3.1 Exponential Functions

# %% [markdown]
# ### f = base^x
#
# ### Different between , f = x^2 , f = u^x
#
# (LATEX)
