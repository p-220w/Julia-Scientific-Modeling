# %% [markdown]
# <a id="table-of-contents"></a>
# # Module 01: Precalculus Basics & Function Representations
#
# ## Table of Contents
# - [1.1 Function Basics](#11-function-basics)
#   - [1.1.1 Define a Function](#define-a-function)
#   - [1.1.2 Vertical Line Test (VLT)](#vertical-line-test)
#   - [1.1.3 Example Functions](#example-functions)
#   - [1.1.4 Multivariable Functions](#multivariable-functions)
# - [1.2 Common Functions](#12-common-functions)
#   - [1.2.1 Linear](#linear-function)
#   - [1.2.2 Quadratic](#quadratic-function)
#   - [1.2.3 Cubics](#cubic-function)
#   - [1.2.4 Square Root](#square-root-function)
#   - [1.2.5 Rational](#rational-function)
#   - [1.2.6 Absolute Value](#absolute-value-function)
#   - [1.2.7 Exponential & Logarithmic](#exponential-function)

# %%
# import Pkg
# Pkg.add(["Plots", "PlotlyJS", "PlotlyBase", "PlotlyKaleido" , "SymPy"])
using Plots
using SymPy
# Activate the interactive Plotly backend
gr(fmt = :svg)
gr()
# I used plotly() btw
# Out:
# Plots.GRBackend()

# %% [markdown]
# <a id="11-function-basics"></a>
# ## 1.1 Function Basics

# %% [markdown]
# <a id="define-a-function"></a>
# ### 1.1.1 Define a Function
#
# **Mathematical Concept:**
# A function assigns exactly one output to each input domain value.
# $$ f(x) = x^2 $$
#
# **Modeling Objective:**
# Programmatically evaluate and visualize a basic mathematical mapping.
#
# [↑ Back to Table of Contents](#table-of-contents)

# %%
f(x) = x.^2
# Out:
# f (generic function with 1 method)

# %%
xV = 0:1:100
plot(xV,f(xV), title = "WOW", size=(600, 400), autosize=true)

# %% [markdown]
# <a id="vertical-line-test"></a>
# ### 1.1.2 Vertical Line Test (VLT)
#
# **Mathematical Concept:**
# A relation is a function if any vertical line intersects its graph at most once.
# $$ y^2 = x \implies y = \pm\sqrt{x} $$
#
# **Modeling Objective:**
# Geometrically demonstrate a non-function relation using vertical line intersections.
#
# [↑ Back to Table of Contents](#table-of-contents)

# %%
vline!([50], label="VLT Line at x=50", color=:red, linestyle=:dash, lw=2)

# %%
x_var = 0:0.1:100
y_p = sqrt.(x_var)
y_n = -sqrt.(x_var)

plot(x_var, y_p, label="y = +√x" ,color=:gray)
plot!(x_var, y_n, label="y = -√x" ,color=:gray)

vline!([25], label="VLT Line at x=25", color=:red, linestyle=:dash, lw=2)

# %% [markdown]
# <a id="example-functions"></a>
# ### 1.1.3 Example Functions

# %% [markdown]
# <a id="example-quadratic"></a>
# #### Quadratic Function
#
# **Mathematical Concept:**
# A symmetric, second-degree polynomial curve forming a parabola.
# $$ f(x) = x^2 $$
#
# **Modeling Objective:**
# Plot symmetric non-linear growth around the origin.
#
# [↑ Back to Table of Contents](#table-of-contents)

# %%
x = -10:0.1:10
f(x) = x.^2

plot(x, f(x), 
     label="f(x) = x^2", 
     title="Symmetric Quadratic Curve around (0,0)", 
     color=:purple, 
     lw=2,
     framestyle=:zerolines,
     grid=true)

# %% [markdown]
# <a id="example-linear"></a>
# #### Linear Function
#
# **Mathematical Concept:**
# A first-degree polynomial representing a constant rate of change.
# $$ f(x) = x $$
#
# **Modeling Objective:**
# Visualize direct proportionality and linear mapping.
#
# [↑ Back to Table of Contents](#table-of-contents)

# %%
x = -100:0.1:100
f(x) = x

plot(x, f(x), 
     label="f(x) = x",
     color=:purple, 
     lw=2,
     framestyle=:zerolines,
     grid=true)

# %% [markdown]
# <a id="example-cubic"></a>
# #### Cubic Function
#
# **Mathematical Concept:**
# A third-degree odd polynomial with origin symmetry.
# $$ f(x) = x^3 $$
#
# **Modeling Objective:**
# Illustrate unbounded accelerated growth and point symmetry.
#
# [↑ Back to Table of Contents](#table-of-contents)

# %%
x = -10:0.1:10
f(x) = x.^3
plot(x, f(x), 
     label="f(x) = x.^3",
     color=:purple, 
     lw=2,
     framestyle=:zerolines,
     grid=true)

# %% [markdown]
# <a id="example-sqrt"></a>
# #### Square Root Function
#
# **Mathematical Concept:**
# The principal inverse of $x^2$, restricted to non-negative reals.
# $$ f(x) = \sqrt{x} $$
#
# **Modeling Objective:**
# Showcase domain restriction and decelerating positive growth.
#
# [↑ Back to Table of Contents](#table-of-contents)

# %%
x = 0:0.1:10
z = sqrt.(x)

plot(x, z, 
     label="f(x) = sqrt(x)",
     color=:purple, 
     lw=2,
     framestyle=:zerolines,
     grid=true)

# %% [markdown]
# <a id="multivariable-functions"></a>
# ### 1.1.4 Multivariable Functions
#
# **Mathematical Concept:**
# Functions mapping multiple independent variables to a single output.
# $$ f(x, y) = x + 2y $$
#
# **Modeling Objective:**
# Demonstrate programmatic evaluation of mathematical models with multiple inputs.
#
# [↑ Back to Table of Contents](#table-of-contents)

# %%
func(x,y) = x + 2y
func(1,2)
# Out:
# 5

# %% [markdown]
# #### More Examples

# %% [markdown]
# <a id="multivariable-paraboloid"></a>
# #### 3D Paraboloid
#
# **Mathematical Concept:**
# A multivariable quadratic function forming a symmetric 3D surface.
# $$ f(x, y) = x^2 + y^2 $$
#
# **Modeling Objective:**
# Render a 3D surface plot to visualize continuous spatial domains.
#
# [↑ Back to Table of Contents](#table-of-contents)

# %%
f(x,y) = x^2 + y^2
x = -5:0.2:5
y = -5:0.2:5

surface(x,y,f, title= "3D Visul of Multivariable", color=:coolwarm, camera=(40,35), zlims=(0, 25) )

# %%
f(x,y) = x^2 + y^2
x = -5:0.2:5
y = -5:0.2:5

surface(x,y,f, title= "3D Visul of Multivariable WITHOUT zlims", color=:coolwarm, camera=(40,35))

# %% [markdown]
# <a id="12-common-functions"></a>
# ## 1.2 Common Functions

# %% [markdown]
# <a id="linear-function"></a>
# ### 1.2.1 Linear

# %% [markdown]
# <a id="linear-latex"></a>
# #### Linear Function
# $$ f(x) = \pm x $$
#
# [↑ Back to Table of Contents](#table-of-contents)

# %%
x = -100:1:100
f(x) = x
fm(x) = -x
plot(x,f, title="Linear" , label="f(x) = x", color=:purple, framestyle=:zerolines)
plot!(x,fm, title="Linear" , label="f(x) = -x", color=:gray, framestyle=:zerolines)

# %% [markdown]
# **Function Properties:**
# * **Domain:** $x \in (-\infty, \infty)$
# * **Range:** $y \in (-\infty, \infty)$
# * **x-intercepts:** $(0, 0)$
# * **y-intercepts:** $(0, 0)$
#
# [↑ Back to Table of Contents](#table-of-contents)

# %% [markdown]
# <a id="quadratic-function"></a>
# ### 1.2.2 Quadratic

# %% [markdown]
# <a id="quadratic-latex"></a>
# #### Quadratic Function
# $$ f(x) = x^2 $$
#
# [↑ Back to Table of Contents](#table-of-contents)

# %%
x = -100:1:100
f(x) = 2x^2 
plot(x,f, title="Quadratic" , label="f(x) = x^2", color=:purple, framestyle=:zerolines)

# %% [markdown]
# **Function Properties:**
# * **Domain:** $x \in (-\infty, \infty)$
# * **Range:** $y \in [0, \infty)$
# * **x-intercepts:** $(0, 0)$
# * **y-intercepts:** $(0, 0)$
#
# [↑ Back to Table of Contents](#table-of-contents)

# %% [markdown]
# <a id="cubic-function"></a>
# ### 1.2.3 Cubics

# %% [markdown]
# <a id="cubic-latex"></a>
# #### Cubic Function
# $$ f(x) = x^3 $$
#
# [↑ Back to Table of Contents](#table-of-contents)

# %%
x = -100:1:100
f(x) = x^3
plot(x,f, title="Cubics" , label="f(x) = x^3", color=:purple, framestyle=:zerolines)

# %% [markdown]
# **Function Properties:**
# * **Domain:** $x \in (-\infty, \infty)$
# * **Range:** $y \in (-\infty, \infty)$
# * **x-intercepts:** $(0, 0)$
# * **y-intercepts:** $(0, 0)$
#
# [↑ Back to Table of Contents](#table-of-contents)

# %% [markdown]
# <a id="square-root-function"></a>
# ### 1.2.4 Square Root

# %% [markdown]
# <a id="sqrt-latex"></a>
# #### Square Root Function
# $$ f(x) = \sqrt{x} $$
#
# [↑ Back to Table of Contents](#table-of-contents)

# %%
x = 0:1:100
f(x) = sqrt.(x)
plot(x,f, title="Square root" , label="f(x) = x^3", color=:purple, framestyle=:zerolines)

# %% [markdown]
# **Function Properties:**
# * **Domain:** $x \in [0, \infty)$
# * **Range:** $y \in [0, \infty)$
# * **x-intercepts:** $(0, 0)$
# * **y-intercepts:** $(0, 0)$
#
# [↑ Back to Table of Contents](#table-of-contents)

# %% [markdown]
# <a id="rational-function"></a>
# ### 1.2.5 Rational

# %% [markdown]
# <a id="rational-latex"></a>
# #### Rational Function
# $$ f(x) = \frac{1}{x} $$
#
# [↑ Back to Table of Contents](#table-of-contents)

# %%
x = -10.0:0.1:10.0
f(x) = x == 0 ? NaN : 1/x 

plot(x, f.(x), title="Rational (Reciprocal)", label="f(x) = 1/x", color=:purple, framestyle=:zerolines)

# %% [markdown]
# **Function Properties:**
# * **Domain:** $x \in (-\infty, 0) \cup (0, \infty)$
# * **Range:** $y \in (-\infty, 0) \cup (0, \infty)$
# * **x-intercepts:** None
# * **y-intercepts:** None
#
# [↑ Back to Table of Contents](#table-of-contents)

# %% [markdown]
# <a id="absolute-value-function"></a>
# ### 1.2.6 Absolute Value

# %% [markdown]
# <a id="abs-latex"></a>
# #### Absolute Value Function
# $$ f(x) = |x| $$
#
# [↑ Back to Table of Contents](#table-of-contents)

# %%
x = -100:1:100
f(x) = abs(x)
plot(x,f, title="Absolute Value" , label="f(x) = | x |", color=:purple, framestyle=:zerolines)

# %% [markdown]
# **Function Properties:**
# * **Domain:** $x \in (-\infty, \infty)$
# * **Range:** $y \in [0, \infty)$
# * **x-intercepts:** $(0, 0)$
# * **y-intercepts:** $(0, 0)$
#
# [↑ Back to Table of Contents](#table-of-contents)

# %% [markdown]
# <a id="exponential-function"></a>
# ### 1.2.7 Exponential

# %% [markdown]
# <a id="exp-latex"></a>
# #### Exponential Function
# $$ f(x) = e^x $$
#
# [↑ Back to Table of Contents](#table-of-contents)

# %%
x = -2.5:0.05:2.5
f(x) = exp.(x)
plot(x,f, title="Exponential" , label="f(x) = e^x", color=:purple, framestyle=:zerolines)

# %% [markdown]
# **Function Properties:**
# * **Domain:** $x \in (-\infty, \infty)$
# * **Range:** $y \in (0, \infty)$
# * **x-intercepts:** None
# * **y-intercepts:** $(0, 1)$
#
# [↑ Back to Table of Contents](#table-of-contents)

# %% [markdown]
# <a id="log-latex"></a>
# #### Logarithmic Function
# $$ f(x) = \ln(x) $$
#
# [↑ Back to Table of Contents](#table-of-contents)

# %%
x = 0.01:0.1:10.0
f(x) = log.(x)
plot(x,f, title="Logarithmic" , label="f(x) = ln(x)", color=:purple, framestyle=:zerolines)

# %% [markdown]
# **Function Properties:**
# * **Domain:** $x \in (0, \infty)$
# * **Range:** $y \in (-\infty, \infty)$
# * **x-intercepts:** $(1, 0)$
# * **y-intercepts:** None
#
# [↑ Back to Table of Contents](#table-of-contents)

# %% [markdown]
# <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
# <script>
#   window.addEventListener('load', function() {
#     setTimeout(function() {
#       var plots = document.querySelectorAll('.js-plotly-plot');
#       plots.forEach(function(p) {
#         Plotly.relayout(p, {autosize: true});
#       });
#     }, 1000);
#   });
# </script>
